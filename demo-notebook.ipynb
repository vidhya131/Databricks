# %% [markdown]
# # Welcome to My Notebook
#
# This notebook demonstrates data analysis using **Databricks** and *PySpark*.
#
# ## Key Features
#
# * Fast distributed computing with Apache Spark
# * Interactive data exploration and visualization
# * Seamless integration with Delta Lake
# * Built-in machine learning capabilities
#
# ## Getting Started
#
# 1. Connect to your data source
# 2. Load and explore your data
# 3. Transform and analyze
# 4. Visualize insights
#
# ### Code Example
#
# ```python
# df = spark.read.table("my_catalog.my_schema.my_table")
# display(df)
# ```
#
# ---
#
# > **Note**: Remember to attach this notebook to a running cluster before executing cells.

# %%
print("hi")
a = 10
b = 90
c = a*b
d = b//a
print("How are you?")

# %% [markdown]
# # Magic Commands

# %%
# %fs ls dbfs:/

# %%
# %sh ls /dbfs

# %%
# %%sh
# ls /dbfs
# ls /dbfs

# %%
# This works - mixing Python and shell
print("Before shell command")
# !ls /dbfs
print("After shell command")

# %%
# %%sh
# # This entire cell is now shell mode
# ls /dbfs
# echo "This is a shell command"

# %%
# !fs ls  dbfs:/

# %%
# %%sql
# select "Vidhya";
# select "Vinay"
